# %%
print('Hello, World!')
print("{}.{}@gmail.com".format("Vishwajeet","Sonkhedkar"))
# Out:
# Hello, World!
# Vishwajeet.Sonkhedkar@gmail.com

# %%
class Employee:
    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.email = '{}.{}@gmail.com'.format(first, last)

    def fullname(self):
        return '{} {}'.format(self.first, self.last)

# %%
emp1 = Employee('Vishwajeet', 'Sonkhedkar')
print(emp1.first)
# Out:
# Vishwajeet
